# %% [markdown]
# #                                Athena's Feminints Bookstore
#
#
#
# **Project Goals:**
#
# 1.	Help Athena's Story create successful campaign in March.
# 2.	Use customer survey data to understand their target audience and their preferences for feminist books.
# 3.	Use historical sales data to identify the most profitable genres for Athena's Story, including feminist fiction and biographies of inspiring women, as well as newer genres such as children's literature and feminist zines.
#
# **Objectives:**
#
# 1.	Analyze the customer survey data to understand the target audience's preferences for feminist books and their likelihood of purchasing books during Women's History Month.
# 2.	Analyze the historical sales data to identify patterns and trends in the most profitable genres and to determine the potential for growth in newer genres.
# 3.	Provide recommendations on which types of books to focus on during the campaign, based on the survey and sales data analysis.
#
#
# ## Data Documentation
#
# Customer Survey Dataset The dataset is a collection of responses to a survey about Women's History Month (WHM) celebrations. The survey had six questions, and the responses were collected from an unknown number of participants.
#
# - The first question (Q1) asked whether the respondent planned to celebrate WHM, and the possible answers were "Yes" or "No." - The second question (Q2) was only applicable to those who answered "Yes" to Q1 and asked how they planned to celebrate, and the respondents were asked to write their answers.
#
# - The third question (Q3) asked whether the respondent purchased feminist books in honor of WHM, either for themselves or as a gift for someone else. The possible answers were "Yes" or "No." The fourth question (Q4) was only applicable to those who answered "Yes" to Q3 and asked how many books they typically purchase during March. The possible answers were "1," "2-Mar," "4 or more."
#
# - The fifth question (Q5) asked what the respondent liked most about Athena's Story. The respondents were asked to write their answers. Athena's Story is likely a store or a website that sells feminist books or products related to WHM celebrations.
#
# - The sixth question (Q6) asked what types of books the respondents would like to see more of at Athena's Story. The respondents were asked to write their answers, and the possible answers were "Feminist fiction," "Feminist zines," "Feminist poetry," "Feminist novels and essays," "Women's history books," "Biographies of inspirational women," "Women's journals," and "Feminist science fiction."
#
# *Limitations*
#
#
# - Sample size: The dataset is relatively small, consisting of only 85 responses. This may limit the generalizability of the results to a larger population.
#
# - Self-reported data: The data is self-reported, which means that there may be biases or inaccuracies in the responses. For example, respondents may not remember their actual behavior during Women's History Month or may be inclined to over-report positive behaviors.
#
# - Limited survey questions: The survey only consists of six questions, which may not provide a comprehensive view of the respondents' behaviors and attitudes towards Women's History Month.
#
# - Lack of demographic information: The dataset does not include information about the respondents' age, gender, race, or other demographic characteristics. This information could be helpful in understanding how different groups celebrate or support Women's History Month.
#
# - Limited context: The dataset does not provide information about the respondents' geographic location, socioeconomic status, or cultural background, which may impact their attitudes and behaviors towards Women's History Month.
#
# Historical Sales Dataset consist of the sales of four different genres of products (Feminist Fiction, Biographies Children's Literature, and Feminist Zines) per week for a period of 52 weeks. The sales are in USD and are shown for each week.
#
# We can use this dataset to analyze the sales trends of the different products and determine which ones are more popular. We can also use this data to predict future sales and determine whether there are any seasonal trends or patterns. Additionally, we can compare the sales of different genres and determine which ones are growing in popularity or declining. Overall, this dataset can provide valuable insights into the book market and consumer preferences.
# Customer Survey
#
# *Limitations*
#
# - Limited information: The dataset only includes sales data for four variables (three product genres and one week variable). Other important information, such as the geographic location, store type, marketing campaigns, and pricing strategies, are not included. Without this information, it is difficult to draw meaningful conclusions or make accurate predictions.
#
# - Short time frame: The dataset covers 52 weeks, which may not be sufficient to identify long-term trends or seasonal patterns. It is also possible that the sales patterns in this dataset are unique to this particular year and may not be representative of other years.
#
# - Lack of context: The dataset does not provide any context or explanation for the sales patterns observed. For example, it is unclear why certain genres had higher or lower sales in specific weeks. Without this context, it is difficult to interpret the data or draw conclusions.
#
# - Missing data: There are missing data points in the dataset, such as the missing values in the sales of Feminist Zines in Week 46. This missing data may affect the accuracy of any analysis or conclusions drawn from the dataset.
#
# - No indication of sample size or representativeness: There is no information provided about the sample size of the data or how it was collected. It is also not clear if the dataset is representative of a larger population or if it is a sample of specific stores or locations. Without this information, it is difficult to determine the generalizability of the findings

# %% [markdown]
# ## Data Cleaning and Processing

# %%
#importing the pandas library as pd
import pandas as pd

#Reading the CustomerSurvey.csv file and storing it in the variable 'customer_survey'
cust_survey = pd.read_csv("./data/CustomerSurvey.csv")
#Reading the Historical Sales.csv file and storing it in the variable 'hist_sales'
hist_sales = pd.read_csv("./data/Historical Sales.csv")

# %%
#viewing first 10 rows of hist_sale
hist_sales.head(n=10)
# Out:
#    Week Product 1 (Feminist Fiction) sales per week  \
# 0     1                                     $407.33
# 1     2                                     $345.44
# 2     3                                     $294.33
# 3     4                                     $371.56
# 4     5                                     $314.33
# 5     6                                     $374.89
# 6     7                                     $365.00
# 7     8                                     $409.44
# 8     9                                     $329.78
# 9    10                                     $379.11
#
#   Product 2 (Biographies) sales per week  \
# 0                                $318.78
# 1                                $270.35
# 2                                $230.35
# 3                                $290.78
# 4                                $246.00
# 5                                $293.39
# 6                                $285.65
# 7                                $320.43
# 8                                $258.09
# 9                                $296.70
#
#   NEW genre (Children's Literature) sales per week  \
# 0                                          $106.26
# 1                                           $90.12
# 2                                           $76.78
# 3                                           $96.93
# 4                                           $82.00
# 5                                           $97.80
# 6                                           $95.22
# 7                                          $106.81
# 8                                           $86.03
# 9                                           $98.90
#
#   NEW genre (Feminist Zines) sales per week
# 0                                    $99.08
# 1                                    $84.03
# 2                                    $71.59
# 3                                    $90.38
# 4                                    $76.46
# 5                                    $91.19
# 6                                    $88.78
# 7                                    $99.59
# 8                                    $80.22
# 9                                    $92.22

# %%
# Let's simplify and reman the variables
#creating list with the new variable names fro hist_sale
histSale_col_names = [
    'week', 'fem_fict', 'biographies', 'children_lit', 'fem_zines'
]
#Renaming the column names of the hist_sales dataframe using the list histSale_col_names
hist_sales.columns = histSale_col_names
#Viewing first 10 observations
hist_sales.head(n=10)
# Out:
#    week  fem_fict  biographies  children_lit  fem_zines
# 0     1    407.33       318.78        106.26      99.08
# 1     2    345.44       270.35         90.12      84.03
# 2     3    294.33       230.35         76.78      71.59
# 3     4    371.56       290.78         96.93      90.38
# 4     5    314.33       246.00         82.00      76.46
# 5     6    374.89       293.39         97.80      91.19
# 6     7    365.00       285.65         95.22      88.78
# 7     8    409.44       320.43        106.81      99.59
# 8     9    329.78       258.09         86.03      80.22
# 9    10    379.11       296.70         98.90      92.22

# %%
hist_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   week          52 non-null     int64
#  1   fem_fict      52 non-null     object
#  2   biographies   52 non-null     object
#  3   children_lit  52 non-null     object
#  4   fem_zines     52 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
# Remove the '$' symbol from columns 'fem_fict', 'biographies', 'children_lit', and 'fem_zines'
cols_to_remove_dollar = [
    'fem_fict', 'biographies', 'children_lit', 'fem_zines'
]
hist_sales[cols_to_remove_dollar] = hist_sales[cols_to_remove_dollar].replace(
    '[\$,]', '', regex=True).astype(float)  #converting datatype to float

# Print the updated datatype with removed '$' symbol
print(hist_sales.dtypes)
# Out:
# week              int64
# fem_fict        float64
# biographies     float64
# children_lit    float64
# fem_zines       float64
# dtype: object

# %%
#saving clean dataset to ne variable
hist_sales_clean = hist_sales
hist_sales_clean.head(n=10)
# Out:
#    week  fem_fict  biographies  children_lit  fem_zines
# 0     1    407.33       318.78        106.26      99.08
# 1     2    345.44       270.35         90.12      84.03
# 2     3    294.33       230.35         76.78      71.59
# 3     4    371.56       290.78         96.93      90.38
# 4     5    314.33       246.00         82.00      76.46
# 5     6    374.89       293.39         97.80      91.19
# 6     7    365.00       285.65         95.22      88.78
# 7     8    409.44       320.43        106.81      99.59
# 8     9    329.78       258.09         86.03      80.22
# 9    10    379.11       296.70         98.90      92.22

# %% [markdown]
# Next the customer survey dataset will be processed and cleaned

# %%
#viewing first 10 rows of customer survey dataset
cust_survey.head(n=10)
# Out:
#   Survey Q1: Do you plan to celebrate WHM?   \
# 0                                       Yes
# 1                                       Yes
# 2                                        No
# 3                                       Yes
# 4                                        No
# 5                                        No
# 6                                        No
# 7                                       Yes
# 8                                        No
# 9                                        No
#
#   Survey Q2: If answered "Yes" to Q1, how do you plan to celebrate?  \
# 0                        Support a women’s nonprofit
# 1                   Host an event to celebrate women
# 2  Watch movies directed by women and with female...
# 3                     Support women-owned businesses
# 4                       Spin tunes by female artists
# 5                             Support female authors
# 6  Write positive affirmations on notes and hand ...
# 7  Decorate my bedroom with empowering quotes by ...
# 8  Buy small gifts for my friends with messages o...
# 9  Host a dinner party and have everyone go aroun...
#
#   Survey Q3: Do you purchase feminist books in honor of WHM, either for yourself or as a gift for someone else?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
# 5                                                 No
# 6                                                 No
# 7                                                Yes
# 8                                                 No
# 9                                                 No
#
#   Survey Q4: If answered "Yes" to Q3, how many books do you typically purchase during March?  \
# 0                                                  1
# 1                                                2-3
# 2                                          4 or more
# 3                                                  1
# 4                                                  1
# 5                                                2-3
# 6                                          4 or more
# 7                                                  1
# 8                                                2-3
# 9                                                  1
#
#   Survey Q5: What do you like most about Athena's Story?   \
# 0                                   All of the above
# 1       Product selection relating to women's issues
# 2                                   Friendly service
# 3   Athena's story gives back to the local community
# 4                                   All of the above
# 5                  Supporting a woman-owned business
# 6                 Knowledgable staff recommendations
# 7                                   All of the above
# 8                                   All of the above
# 9                  Supporting a woman-owned business
#
#   Survey Q6: What types of books would you like to see more of at Athena's Story?
# 0                                   Feminist fiction
# 1                                     Feminist zines
# 2                                    Feminist poetry
# 3                         Feminist novels and essays
# 4                 Biographies of inspirational women
# 5                              Women's history books
# 6                                   Feminist fiction
# 7                              Children's literature
# 8                              Children's literature
# 9                                   Feminist fiction

# %%
#printing variable names
print(cust_survey.columns)
# Out:
# Index(['Survey Q1: Do you plan to celebrate WHM? ',
#        'Survey Q2: If answered "Yes" to Q1, how do you plan to celebrate?',
#        'Survey Q3: Do you purchase feminist books in honor of WHM, either for yourself or as a gift for someone else?',
#        'Survey Q4: If answered "Yes" to Q3, how many books do you typically purchase during March?',
#        'Survey Q5: What do you like most about Athena's Story? ',
#        'Survey Q6: What types of books would you like to see more of at Athena's Story?'],
#       dtype='object')

# %%
#creating a dictionary for the customer survey dataset new variable names
cust_survey_VariableNames = {
    'Survey Q1: Do you plan to celebrate WHM? ':
    'Q1',
    'Survey Q2: If answered "Yes" to Q1, how do you plan to celebrate?':
    'Q2',
    'Survey Q3: Do you purchase feminist books in honor of WHM, either for yourself or as a gift for someone else?':
    'Q3',
    'Survey Q4: If answered "Yes" to Q3, how many books do you typically purchase during March?':
    'Q4',
    'Survey Q5: What do you like most about Athena\'s Story? ':
    'Q5',
    'Survey Q6: What types of books would you like to see more of at Athena\'s Story?':
    'Q6'
}

# Rename the columns of the dataset using the dictionary
cust_survey = cust_survey.rename(columns=cust_survey_VariableNames)

#view
cust_survey.head(n=10)
# Out:
#     Q1                                                 Q2   Q3         Q4  \
# 0  Yes                        Support a women’s nonprofit   No          1
# 1  Yes                   Host an event to celebrate women  Yes        2-3
# 2   No  Watch movies directed by women and with female...   No  4 or more
# 3  Yes                     Support women-owned businesses   No          1
# 4   No                       Spin tunes by female artists   No          1
# 5   No                             Support female authors   No        2-3
# 6   No  Write positive affirmations on notes and hand ...   No  4 or more
# 7  Yes  Decorate my bedroom with empowering quotes by ...  Yes          1
# 8   No  Buy small gifts for my friends with messages o...   No        2-3
# 9   No  Host a dinner party and have everyone go aroun...   No          1
#
#                                                  Q5  \
# 0                                  All of the above
# 1      Product selection relating to women's issues
# 2                                  Friendly service
# 3  Athena's story gives back to the local community
# 4                                  All of the above
# 5                 Supporting a woman-owned business
# 6                Knowledgable staff recommendations
# 7                                  All of the above
# 8                                  All of the above
# 9                 Supporting a woman-owned business
#
#                                    Q6
# 0                    Feminist fiction
# 1                      Feminist zines
# 2                     Feminist poetry
# 3          Feminist novels and essays
# 4  Biographies of inspirational women
# 5               Women's history books
# 6                    Feminist fiction
# 7               Children's literature
# 8               Children's literature
# 9                    Feminist fiction

# %%
cust_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q1      84 non-null     object
#  1   Q2      32 non-null     object
#  2   Q3      65 non-null     object
#  3   Q4      16 non-null     object
#  4   Q5      84 non-null     object
#  5   Q6      84 non-null     object
# dtypes: object(6)
# memory usage: 4.1+ KB

# %% [markdown]
# In the given dataset, we can see that there are missing values in Survey Q2, Survey Q3, and Survey Q4. In Survey Q3 there are missing under the assumption that the participants did not fill out this part of the questionere. For the missing values in Survey Q2 and Survey Q4, we can replace them with "Not applicable" as those questions are only applicable if the answer to Survey Q1 and Survey Q3 is "Yes," respectively.
#
# So, we can replace the missing values in Survey Q2, Q4 and Survey Q3 with "Not applicable," account for not applicable and missing values

# %%
cust_survey.tail(20)
# Out:
#      Q1   Q2   Q3   Q4                                                Q5  \
# 64   No  NaN   No  NaN                                  All of the above
# 65   No  NaN  NaN  NaN                 Supporting a woman-owned business
# 66   No  NaN  NaN  NaN                                  Friendly service
# 67  Yes  NaN  NaN  NaN  Athena's story gives back to the local community
# 68   No  NaN  NaN  NaN                                  All of the above
# 69   No  NaN  NaN  NaN      Product selection relating to women's issues
# 70   No  NaN  NaN  NaN                Knowledgable staff recommendations
# 71  Yes  NaN  NaN  NaN                                  All of the above
# 72  Yes  NaN  NaN  NaN                                  All of the above
# 73   No  NaN  NaN  NaN      Product selection relating to women's issues
# 74  Yes  NaN  NaN  NaN                                  Friendly service
# 75   No  NaN  NaN  NaN  Athena's story gives back to the local community
# 76   No  NaN  NaN  NaN                                  All of the above
# 77   No  NaN  NaN  NaN                 Supporting a woman-owned business
# 78   No  NaN  NaN  NaN                Knowledgable staff recommendations
# 79  Yes  NaN  NaN  NaN                                  All of the above
# 80   No  NaN  NaN  NaN                                  All of the above
# 81   No  NaN  NaN  NaN                 Supporting a woman-owned business
# 82  Yes  NaN  NaN  NaN                                  Friendly service
# 83  Yes  NaN  NaN  NaN  Athena's story gives back to the local community
#
#                                     Q6
# 64  Biographies of inspirational women
# 65                      Feminist zines
# 66                    Feminist fiction
# 67               Children's literature
# 68  Biographies of inspirational women
# 69               Children's literature
# 70  Biographies of inspirational women
# 71                      Feminist zines
# 72  Biographies of inspirational women
# 73               Children's literature
# 74                    Feminist fiction
# 75                      Feminist zines
# 76                    Feminist fiction
# 77               Children's literature
# 78                      Feminist zines
# 79  Biographies of inspirational women
# 80                    Feminist fiction
# 81                    Feminist fiction
# 82                    Feminist fiction
# 83  Biographies of inspirational women

# %%
cust_survey.describe()
# Out:
#         Q1                              Q2  Q3  Q4                Q5  \
# count   84                              32  65  16                84
# unique   2                              24   2   3                 6
# top     No  Support women-owned businesses  No   1  All of the above
# freq    51                               3  50   7                30
#
#                       Q6
# count                 84
# unique                12
# top     Feminist fiction
# freq                  22

# %%
cust_survey['Q5'].value_counts()
# Out:
# All of the above                                    30
# Supporting a woman-owned business                   12
# Athena's story gives back to the local community    11
# Knowledgable staff recommendations                  11
# Product selection relating to women's issues        10
# Friendly service                                    10
# Name: Q5, dtype: int64

# %%
cust_survey['Q2'].value_counts()
# Out:
# nan                                                                                                              52
# Support women-owned businesses                                                                                    3
# Decorate my bedroom with empowering quotes by women                                                               2
# Buy books by female authors                                                                                       2
# Shop at women-owned businesses                                                                                    2
# Host a dinner for my female friends                                                                               2
# Support women authors and artists                                                                                 2
# Support female authors                                                                                            2
# Write positive affirmations on notes and hand them out                                                            1
# Chill with my girlfriends to some feminist TV shows                                                               1
# Have a mini ceremony and give out awards to each of my girlfriends to celebrate their accomplishments             1
# Share quotes on social media                                                                                      1
# Watch movies directed by women and with female leads                                                              1
# Spin tunes by female artists                                                                                      1
# Volunteer my time at a women’s nonprofit                                                                          1
# Support female-owned companies                                                                                    1
# Make a collage of art by women like Frida Kahlo and Georgia O’Keefe                                               1
# Buy small gifts for my friends with messages of empowerment                                                       1
# Volunteer at a feminist nonprofit                                                                                 1
# Start a mentorship with a female coworker                                                                         1
# Host an event to celebrate women                                                                                  1
# Write a thank you note to a woman that inspires me                                                                1
# Buy some girl-power swag                                                                                          1
# Host a dinner party and have everyone go around the table saying how they're going to support women this year     1
# Support a women’s nonprofit                                                                                       1
# Name: Q2, dtype: int64

# %%
cust_survey['Q6'].value_counts()
# Out:
# Feminist fiction                      22
# Biographies of inspirational women    17
# Children's literature                 13
# Feminist zines                        12
# Feminist poetry                        4
# Feminist science fiction               4
# Feminist novels and essays             3
# Women's history books                  2
# Feminist literary criticism            2
# Books about women in the arts          2
# Women's journals                       2
# Women's world studies                  1
# Name: Q6, dtype: int64

# %% [markdown]
# ## Vizualization

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette("Paired")
# set plot style: grey grid in the background:
sns.set(style="white")

# Set the figure size
plt.figure(figsize=(5, 5))

# plot a bar chart
# Create a count plot using Seaborn
ax = sns.countplot(y='Q1',
                   data=cust_survey,
                   linewidth=1,
                   edgecolor='black',
                   palette='Paired')
plt.title('Percentage of Customers Celebrating Women History Month\n',
          fontname='Times New Roman',
          fontsize=14,
          fontweight='light')
plt.ylabel('Planning to celebrate WHM\n',
           fontname='Times New Roman',
           fontsize=12,
           fontweight='light')
ax.set_yticklabels(ax.get_yticklabels(),
                   fontname='Times New Roman',
                   fontsize=10)
#remove x-axis label
plt.xlabel(' ')  #create code to remove tile

# remove the spines
sns.despine()

# remove the x-axis line
sns.despine(bottom=True)
# Remove x-axis
ax.set(xticks=[])

#loop through each bar in the countplot and add a text annotation with the percentage value
total = len(cust_survey['Q1'])
palette = sns.color_palette("Paired")  # define color palette

for i, p in enumerate(ax.patches):
    percentage = '    {:.1f}%'.format(100 * p.get_width() / total)
    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y),
                color=palette[i % len(palette)],
                fontweight="bold")

#View
plt.show()

# %% [markdown]
# Analysis
#
# #######
# #######
# #######

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette("Paired")
# set plot style: grey grid in the background:
sns.set(style="white")

# Set the figure size
plt.figure(figsize=(5, 5))

# plot a bar chart
# Create a count plot using Seaborn
ax = sns.countplot(y='Q3',
                   data=cust_survey,
                   linewidth=1,
                   edgecolor='black',
                   palette='Paired')
plt.title(
    'Percentage Customers Purchasing Feminist Books\n in Honor Women History Month',
    fontname='Times New Roman',
    fontsize=14,
    fontweight='light')
plt.ylabel('Purchasing Feminist Book in Honor of WHM\n',
           fontname='Times New Roman',
           fontsize=12,
           fontweight='light')
ax.set_yticklabels(ax.get_yticklabels(),
                   fontname='Times New Roman',
                   fontsize=10)
#remove x-axis label
plt.xlabel(' ')  #create code to remove tile

# remove the spines
sns.despine()

# remove the x-axis line
sns.despine(bottom=True)
# Remove x-axis
ax.set(xticks=[])

#loop through each bar in the countplot and add a text annotation with the percentage value
total = len(cust_survey['Q3'])
palette = sns.color_palette("Paired")  # define color palette

for i, p in enumerate(ax.patches):
    percentage = '    {:.1f}%'.format(100 * p.get_width() / total)
    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y),
                color=palette[i % len(palette)],
                fontweight="bold")

#View
plt.show()

# %% [markdown]
# Analysis

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette("Paired")
# set plot style: grey grid in the background:
sns.set(style="white")

# Set the figure size
plt.figure(figsize=(5, 5))

# plot a bar chart
# Create a count plot using Seaborn
ax = sns.countplot(y='Q4',
                   data=cust_survey,
                   linewidth=1,
                   edgecolor='black',
                   palette='Paired')
plt.title(
    'Amount of Books Customers Purchase\n During Women History Month (%)\n',
    fontname='Times New Roman',
    fontsize=14,
    fontweight='light')
plt.ylabel('Amount of Books\n',
           fontname='Times New Roman',
           fontsize=12,
           fontweight='light')
ax.set_yticklabels(ax.get_yticklabels(),
                   fontname='Times New Roman',
                   fontsize=12)
#remove x-axis label
plt.xlabel(' ')  #create code to remove tile

# remove the spines
sns.despine()

# remove the x-axis line
sns.despine(bottom=True)
# Remove x-axis
ax.set(xticks=[])

#loop through each bar in the countplot and add a text annotation with the percentage value
total = len(cust_survey['Q4'])
palette = sns.color_palette("Paired")  # define color palette

for i, p in enumerate(ax.patches):
    percentage = '    {:.1f}%'.format(100 * p.get_width() / total)
    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y),
                color=palette[i % len(palette)],
                fontweight="bold")

#View
plt.show()

# %% [markdown]
# Analysis

# %%
#impor wordcloud library
from wordcloud import WordCloud

#converting to strings
cust_survey['Q2'] = cust_survey['Q2'].astype(str)

# Add custom stopwords to the default list of stopwords
stopwords = set([
    'going', 'by', 'and', 'the', 'to', 'in', 'of', 'a', 'is', 'that', 'it',
    'with', 'my', 'some', 'small', 'an', 'you', 'mini', 'like', 'for', 'on',
    'at', 'have', 'out', 'bedroom', "they're", 's', 'around', 'how', 'this',
    'hand'
])

# join the Q2 column into a single string, excluding 'nan' values
text = " ".join(review for review in cust_survey['Q2'] if review != 'nan')

# Generate a word cloud image
wordcloud = WordCloud(width=800,
                      height=400,
                      colormap='Paired',
                      background_color='white',
                      stopwords=stopwords,
                      max_words=100).generate(text)

# Display the generated image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='spline16')
plt.axis('off')
plt.show()

# %% [markdown]
# Analysis
